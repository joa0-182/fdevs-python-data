# %% [markdown]
# # Aula 01 – Introdução ao Pandas
#
# ## Objetivo da aula
#
# Nesta aula vamos aprender o básico da biblioteca **Pandas**, usada para trabalhar com dados em Python.
#
# Você irá aprender:
#
# - Importar o Pandas
# - Ler uma base de dados
# - Visualizar os dados
# - Entender **Series** e **DataFrame**
# - Analisar estrutura e tipos das colunas

# %% [markdown]
# # 1. Importando o Pandas
#
# O **Pandas** é a biblioteca mais utilizada para manipulação de dados em Python.
#
# Ela é normalmente importada com o apelido **pd**.

# %%
import pandas as pd

# %% [markdown]
# # 2. Lendo um arquivo de dados
#
# Vamos carregar uma base utilizando o Pandas.

# %%
arquivo = r"C:\Users\Joao.Maria\Documents\curso-python_joao_pedro\Base\Base_analitica_vendas.xlsx"

base_vendas = pd.read_excel(arquivo, sheet_name="Base")

# %% [markdown]
# Agora a variável **base_vendas** contém toda a tabela carregada.

# %% [markdown]
# # 3. Visualizando os dados
#
# Existem algumas formas simples de visualizar um DataFrame.
#
# ### Primeiras linhas da base

# %%
base_vendas.head(5)
# Out:
#   DATAEMISSAO  CODIGOCLIENTE      DESCRICAOCLIENTE  CODIGOGRUPOPRODUTO  \
# 0  2026-02-01       10000449  ATACADO BRINDE & CIA            90013006
# 1  2026-02-01       10000449  ATACADO BRINDE & CIA            90013011
# 2  2026-02-01       10000449  ATACADO BRINDE & CIA            90013014
# 3  2026-02-01       10000449  ATACADO BRINDE & CIA            90013014
# 4  2026-02-01       10000449  ATACADO BRINDE & CIA            90013022
#
#               DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 0    Bebidas Funcionais Vitaminadas       10022282
# 1       Cervejas Lager Tradicionais       10001628
# 2            Sucos Naturais Premium       10008337
# 3            Sucos Naturais Premium       10021324
# 4  Insumos para Produção de Bebidas       10026538
#
#                            NOMEPRODUTO  TIPOFATURAMENTO  \
# 0       Isotônico Uva Vitaminado 500ml                1
# 1  Cerveja Lager Standard 350ml (Lata)                1
# ...

# %% [markdown]
# ### Ultimas linhas da base

# %%
base_vendas.tail(3)
# Out:
#       DATAEMISSAO  CODIGOCLIENTE              DESCRICAOCLIENTE  \
# 40618  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 40619  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 40620  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
#
#        CODIGOGRUPOPRODUTO    DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 40618            91503409  Bebidas Prontas Geladas       10021535
# 40619            91503409  Bebidas Prontas Geladas       10021536
# 40620            91503409  Bebidas Prontas Geladas       10021537
#
#                         NOMEPRODUTO  TIPOFATURAMENTO DESCRICAOTIPOFATURAMENTO  \
# 40618      Hard Seltzer Amora 310ml                1                    VENDA
# 40619  Hard Seltzer Tangerina 310ml                1                    VENDA
# 40620    Hard Seltzer Abacaxi 310ml                1                    VENDA
#
#        VOLUME  VALORLIQUIDO
# 40618       9       1553.94
# 40619      10       1845.10
# 40620       1         88.88

# %% [markdown]
# ### Amostragem de dados (linhas aleatórias)

# %%
base_vendas.sample(3)
# Out:
#       DATAEMISSAO  CODIGOCLIENTE                 DESCRICAOCLIENTE  \
# 15813  2026-02-13       10000964      LOGÍSTICA ESSENCIAL BEBIDAS
# 35394  2026-02-24       10004237      LOGÍSTICA MUNDO DAS BEBIDAS
# 21177  2026-02-15       10004231  DISTRIBUIDORA REINO DAS BEBIDAS
#
#        CODIGOGRUPOPRODUTO             DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 15813            90013022  Insumos para Produção de Bebidas       10026538
# 35394            90013172         Bebidas Mistas Alcoólicas       10015859
# 21177            90013011       Cervejas Lager Tradicionais       10001628
#
#                                NOMEPRODUTO  TIPOFATURAMENTO  \
# 15813  Lúpulo em Pellet para Brassagem 5kg                1
# 35394        Drink Misto Green Apple 269ml                1
# 21177  Cerveja Lager Standard 350ml (Lata)                1
#
#       DESCRICAOTIPOFATURAMENTO  VOLUME  VALORLIQUIDO
# 15813                    VENDA     400       5944.18
# ...

# %% [markdown]
# ### Mostrar a tabela completa

# %%
display(base_vendas)
# Out:
#       DATAEMISSAO  CODIGOCLIENTE              DESCRICAOCLIENTE  \
# 0      2026-02-01       10000449          ATACADO BRINDE & CIA
# 1      2026-02-01       10000449          ATACADO BRINDE & CIA
# 2      2026-02-01       10000449          ATACADO BRINDE & CIA
# 3      2026-02-01       10000449          ATACADO BRINDE & CIA
# 4      2026-02-01       10000449          ATACADO BRINDE & CIA
# ...           ...            ...                           ...
# 40616  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 40617  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 40618  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 40619  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 40620  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
#
#        CODIGOGRUPOPRODUTO             DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 0                90013006    Bebidas Funcionais Vitaminadas       10022282
# ...

# %% [markdown]
# ### Exibir diretamente a variável

# %%
base_vendas
# Out:
#       DATAEMISSAO  CODIGOCLIENTE              DESCRICAOCLIENTE  \
# 0      2026-02-01       10000449          ATACADO BRINDE & CIA
# 1      2026-02-01       10000449          ATACADO BRINDE & CIA
# 2      2026-02-01       10000449          ATACADO BRINDE & CIA
# 3      2026-02-01       10000449          ATACADO BRINDE & CIA
# 4      2026-02-01       10000449          ATACADO BRINDE & CIA
# ...           ...            ...                           ...
# 40616  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 40617  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 40618  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 40619  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 40620  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
#
#        CODIGOGRUPOPRODUTO             DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 0                90013006    Bebidas Funcionais Vitaminadas       10022282
# ...

# %% [markdown]
# # 4. Estrutura do Pandas
#
# O Pandas possui duas estruturas principais:
#
# | Estrutura | Descrição |
# |---|---|
# | **Series** | Uma única coluna |
# | **DataFrame** | Uma tabela com várias colunas |

# %% [markdown]
# ## 4.1 Series (uma coluna)
#
# Uma **Series** representa apenas uma coluna da base.

# %%
serie_clientes = base_vendas["DESCRICAOCLIENTE"]

serie_clientes
# Out:
# 0                ATACADO BRINDE & CIA
# 1                ATACADO BRINDE & CIA
# 2                ATACADO BRINDE & CIA
# 3                ATACADO BRINDE & CIA
# 4                ATACADO BRINDE & CIA
#                      ...
# 40616    DISTRIBUIDORA ATLETA BEBIDAS
# 40617    DISTRIBUIDORA ATLETA BEBIDAS
# 40618    DISTRIBUIDORA ATLETA BEBIDAS
# 40619    DISTRIBUIDORA ATLETA BEBIDAS
# 40620    DISTRIBUIDORA ATLETA BEBIDAS
# Name: DESCRICAOCLIENTE, Length: 40621, dtype: object

# %% [markdown]
# Verificando o tipo da estrutura:

# %%
type(serie_clientes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## 4.2 DataFrame (tabela)
#
# Um **DataFrame** representa uma tabela completa.

# %%
type(base_vendas)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Também podemos criar um DataFrame selecionando colunas específicas.

# %%
dataframe_clientes = base_vendas[["DESCRICAOCLIENTE"]]

dataframe_clientes
# Out:
#                    DESCRICAOCLIENTE
# 0              ATACADO BRINDE & CIA
# 1              ATACADO BRINDE & CIA
# 2              ATACADO BRINDE & CIA
# 3              ATACADO BRINDE & CIA
# 4              ATACADO BRINDE & CIA
# ...                             ...
# 40616  DISTRIBUIDORA ATLETA BEBIDAS
# 40617  DISTRIBUIDORA ATLETA BEBIDAS
# 40618  DISTRIBUIDORA ATLETA BEBIDAS
# 40619  DISTRIBUIDORA ATLETA BEBIDAS
# 40620  DISTRIBUIDORA ATLETA BEBIDAS
#
# [40621 rows x 1 columns]

# %% [markdown]
# Verificando o tipo:

# %%
type(dataframe_clientes)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 5. Estrutura da base de dados
#
# Podemos analisar a estrutura da base com algumas propriedades importantes.
#
# ### Colunas da base

# %%
base_vendas.columns
# Out:
# Index(['DATAEMISSAO', 'CODIGOCLIENTE', 'DESCRICAOCLIENTE',
#        'CODIGOGRUPOPRODUTO', 'DESCRICAOGRUPOPRODUTO', 'CODIGOPRODUTO',
#        'NOMEPRODUTO', 'TIPOFATURAMENTO', 'DESCRICAOTIPOFATURAMENTO', 'VOLUME',
#        'VALORLIQUIDO'],
#       dtype='object')

# %% [markdown]
# Também é possível converter para lista:

# %%
list(base_vendas.columns)
# Out:
# ['DATAEMISSAO',
#  'CODIGOCLIENTE',
#  'DESCRICAOCLIENTE',
#  'CODIGOGRUPOPRODUTO',
#  'DESCRICAOGRUPOPRODUTO',
#  'CODIGOPRODUTO',
#  'NOMEPRODUTO',
#  'TIPOFATURAMENTO',
#  'DESCRICAOTIPOFATURAMENTO',
#  'VOLUME',
#  'VALORLIQUIDO']

# %% [markdown]
# ### Tamanho da base
#
# Mostra **linhas e colunas**.

# %%
base_vendas.shape
# Out:
# (40621, 11)

# %% [markdown]
# # 6. Tipos de dados
#
# O Pandas interpreta automaticamente o tipo de cada coluna.

# %%
base_vendas.dtypes
# Out:
# DATAEMISSAO                 datetime64[ns]
# CODIGOCLIENTE                        int64
# DESCRICAOCLIENTE                    object
# CODIGOGRUPOPRODUTO                   int64
# DESCRICAOGRUPOPRODUTO               object
# CODIGOPRODUTO                        int64
# NOMEPRODUTO                         object
# TIPOFATURAMENTO                      int64
# DESCRICAOTIPOFATURAMENTO            object
# VOLUME                               int64
# VALORLIQUIDO                       float64
# dtype: object

# %% [markdown]
# # 7. Informações gerais da base
#
# A função **info()** mostra:
#
# - nome das colunas
# - tipo de dados
# - quantidade de valores nulos

# %%
base_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40621 entries, 0 to 40620
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATAEMISSAO               40621 non-null  datetime64[ns]
#  1   CODIGOCLIENTE             40621 non-null  int64
#  2   DESCRICAOCLIENTE          40621 non-null  object
#  3   CODIGOGRUPOPRODUTO        40621 non-null  int64
#  4   DESCRICAOGRUPOPRODUTO     40621 non-null  object
#  5   CODIGOPRODUTO             40621 non-null  int64
#  6   NOMEPRODUTO               40621 non-null  object
#  7   TIPOFATURAMENTO           40621 non-null  int64
#  8   DESCRICAOTIPOFATURAMENTO  40621 non-null  object
#  9   VOLUME                    40621 non-null  int64
#  10  VALORLIQUIDO              40621 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(4)
# memory usage: 3.4+ MB

# %% [markdown]
# # 8. Resumo matemático das colunas numéricas
#
# A função **describe()** é o canivete suíço da estatística, onde mostra:
#
# - Média, valor mínimo, valor máximo, desvio padrão
# - Foca apenas nas colunas numéricas

# %%
base_vendas.describe()
# Out:
#                          DATAEMISSAO  CODIGOCLIENTE  CODIGOGRUPOPRODUTO  \
# count                          40621   4.062100e+04        4.062100e+04
# mean   2026-02-14 19:14:50.583688192   1.000386e+07        9.030686e+07
# min              2026-02-01 00:00:00   1.000045e+07        9.001300e+07
# 25%              2026-02-08 00:00:00   1.000400e+07        9.001306e+07
# 50%              2026-02-15 00:00:00   1.000421e+07        9.001316e+07
# 75%              2026-02-22 00:00:00   1.000423e+07        9.001317e+07
# max              2026-02-28 00:00:00   1.000500e+07        9.150341e+07
# std                              NaN   9.718213e+02        5.928791e+05
#
#        CODIGOPRODUTO  TIPOFATURAMENTO        VOLUME  VALORLIQUIDO
# count   4.062100e+04     40621.000000  40621.000000  4.062100e+04
# mean    1.039773e+07         1.414810     31.207700  3.136858e+03
# min     1.000116e+07         1.000000   -300.000000 -1.851525e+04
# ...
